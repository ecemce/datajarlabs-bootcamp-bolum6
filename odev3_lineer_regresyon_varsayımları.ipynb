# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from scipy.stats.mstats import winsorize
import warnings

# %%
df = pd.read_csv('weather.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df = df[['Humidity','Wind Speed (km/h)', 'Pressure (millibars)','Temperature (C)']]
Y = df[['Temperature (C)']]
X = df[['Humidity','Wind Speed (km/h)', 'Pressure (millibars)']]

# %%
lrm = linear_model.LinearRegression()
lrm.fit(X,Y)
tahmin = lrm.predict(X)
print('Değişkenler:', lrm.coef_)
print('Sabit değer (bias): ', lrm.intercept_)
# Out:
# Değişkenler: [[-3.24398999e+01 -1.94546893e-01 -7.15579969e-04]]
# Sabit değer (bias):  [38.59379935]

# %% [markdown]
# ### VARSAYIM-2  Hata terimi ortalamada sıfır olmalıdır

# %%
hatalar = Y - tahmin
print("modelinin ortalama hatası : {} ".format(np.mean(hatalar)))
# Out:
# modelinin ortalama hatası : Temperature (C)   -8.369815e-15
# dtype: float64

# %% [markdown]
# ### VARSAYIM-3 Homoscedasticity

# %%
baslik_font = {'family': 'arial','color':  'darkred','weight': 'bold','size': 15 }
eksen_font = {'family': 'arial','color':  'darkblue','weight': 'bold','size': 10 }

plt.figure(figsize=(9,6), dpi=90)
plt.scatter(tahmin, hatalar)
plt.xlabel('Tahmin Edilen', fontdict=eksen_font)
plt.ylabel('Artık (Residual)', fontdict=eksen_font)
plt.axhline(y=0)
plt.title('Artık x Tahmin', fontdict=baslik_font)
plt.show()

# %% [markdown]
# ### Bartlett ve Levene Testleri

# %%
from scipy.stats import bartlett
from scipy.stats import levene

bart_stats = bartlett(tahmin, hatalar)
lev_stats = levene(tahmin, hatalar)

print("Bartlett test değeri : {} ve p değeri : {}".format(bart_stats[0], bart_stats[1]))
print("Levene test değeri   : {} ve p değeri : {}".format(lev_stats[0], lev_stats[1]))
# Out:
# Bartlett test değeri : 2595.3385952614226 ve p değeri : 0.0
# Levene test değeri   : [2435.45049023] ve p değeri : [0.]

# %% [markdown]
# ikisinde de p value <0.5 bu da Heteroscedastic olduğu anlamına gelir

# %% [markdown]
# ### VARSAYIM-4 Düşük çoklu doğrusallık/low multicollinearity

# %%
corr_mat = df.corr()
corr_mat
# Out:
#                       Humidity  Wind Speed (km/h)  Pressure (millibars)  \
# Humidity              1.000000          -0.224951              0.005454
# Wind Speed (km/h)    -0.224951           1.000000             -0.049263
# Pressure (millibars)  0.005454          -0.049263              1.000000
# Temperature (C)      -0.632255           0.008957             -0.005447
#
#                       Temperature (C)
# Humidity                    -0.632255
# Wind Speed (km/h)            0.008957
# Pressure (millibars)        -0.005447
# Temperature (C)              1.000000

# %% [markdown]
# ### Varsayım-5: Hata terimleri birbiriyle ilişkisiz olmalıdır

# %%
plt.figure(figsize=(9,6))
plt.plot(hatalar)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_data = acf(hatalar)

plt.figure(figsize=(9,6))
plt.plot(acf_data[1:])
plt.show()

# %% [markdown]
# Hatalar arasındaki korelasyon ilişkisi çok yüksektir.

# %%
df['Hata'] = hatalar
df.corr()
# Out:
#                           Humidity  Wind Speed (km/h)  Pressure (millibars)  \
# Humidity              1.000000e+00      -2.249515e-01          5.454263e-03
# Wind Speed (km/h)    -2.249515e-01       1.000000e+00         -4.926281e-02
# Pressure (millibars)  5.454263e-03      -4.926281e-02          1.000000e+00
# Temperature (C)      -6.322547e-01       8.956968e-03         -5.447106e-03
# Hata                 -2.224321e-15       9.303495e-16         -8.274981e-16
#
#                       Temperature (C)          Hata
# Humidity                    -0.632255 -2.224321e-15
# Wind Speed (km/h)            0.008957  9.303495e-16
# Pressure (millibars)        -0.005447 -8.274981e-16
# Temperature (C)              1.000000  7.625418e-01
# Hata                         0.762542  1.000000e+00

# %%
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# Matrisimizi incelediğimizde hata değişkeninin diğer özelliklerle olan ilişkinin düşük olduğu gözükmektedir.

# %%
from scipy.stats import jarque_bera
from scipy.stats import normaltest
jb_stats = jarque_bera(hatalar)
norm_stats = normaltest(hatalar)

print("Jarque-Bera test değeri : ", jb_stats)
print("Normal test değeri      : " , norm_stats)
# Out:
# Jarque-Bera test değeri :  (3852.0430009381244, 0.0)
# Normal test değeri      :  NormaltestResult(statistic=array([3420.50778308]), pvalue=array([0.]))

# %% [markdown]
# p değeri çok düşüktür.normal dağılıma uymuyor.

# %%
rand_nums = np.random.normal(np.mean(hatalar), np.std(hatalar), len(hatalar))

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(rand_nums, hatalar)
plt.xlabel("Normal dağılımlı rastgele değişken", fontdict=eksen_font)
plt.ylabel("Modelin hataları", fontdict=eksen_font)
plt.title("QQ plotu", fontdict=baslik_font)
# Out:
# Text(0.5, 1.0, 'QQ plotu')

# %% [markdown]
# zaten modelden de hataların normal dağılmadığı gözüküyor.

# %% [markdown]
# ## EV FİYATLARI

# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', 105)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
sns.set()
from subprocess import check_output
import warnings
from sklearn import linear_model
from scipy.stats.mstats import winsorize

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
missing =df_train.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
df_train = df_train.drop([ 'PoolQC','MiscFeature', 'Alley','Fence','FireplaceQu','LotFrontage'], axis = 1)
df_train = df_train.dropna()

# %%
corrmat = df_train.corr()
top_corr_features = corrmat.index[abs(corrmat["SalePrice"])>0.5]
plt.figure(figsize=(10,10))
g = sns.heatmap(df_train[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
dff = df_train[['GrLivArea', 'OverallQual', 'GarageCars', 'SalePrice']]

# %%
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

plt.boxplot(dff["GrLivArea"],whis=1.5)
plt.title("Population kutu grafiği (whis=1.5)", fontdict=baslik_font)
plt.show()

winsorize_GrLivArea= winsorize(dff["GrLivArea"], (0 , 0.01))

winsorize_GrLivArea

plt.boxplot(winsorize_GrLivArea,whis=4)
plt.title("GrLivArea kutu grafiği (whis=1.5)", fontdict=baslik_font)
plt.show()

# %%
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

plt.boxplot(dff["GarageCars"],whis=1.5)
plt.title("GarageCars kutu grafiği (whis=1.5)", fontdict=baslik_font)
plt.show()

winsorize_GarageCars= winsorize(dff["GarageCars"], (0 , 0.01))

winsorize_GarageCars

plt.boxplot(winsorize_GarageCars,whis=4)
plt.title("GarageCars kutu grafiği (whis=1.5)", fontdict=baslik_font)
plt.show()

# %%
dff.head()
# Out:
#    GrLivArea  OverallQual  GarageCars  SalePrice
# 0       1710            7           2     208500
# 1       1262            6           2     181500
# 2       1786            7           2     223500
# 3       1717            7           3     140000
# 4       2198            8           3     250000

# %%
Y = dff[['SalePrice']]
X = dff[['GrLivArea','OverallQual', 'GarageCars']]

# %%
lrm = linear_model.LinearRegression()
lrm.fit(X,Y)
tahmin = lrm.predict(X)
print('Değişkenler:', lrm.coef_)
print('Sabit değer (bias): ', lrm.intercept_)
# Out:
# Değişkenler: [[   51.37711731 27535.69072333 25205.94889448]]
# Sabit değer (bias):  [-110671.17154957]

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     1221.
# Date:                Sun, 19 May 2019   Prob (F-statistic):               0.00
# Time:                        16:03:47   Log-Likelihood:                -16102.
# No. Observations:                1338   AIC:                         3.221e+04
# Df Residuals:                    1334   BIC:                         3.223e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.107e+05   5368.231    -20.616      0.000   -1.21e+05      -1e+05
# ...

# %%
hatalar = Y - tahmin
print("modelinin ortalama hatası : {} ".format(np.mean(hatalar)))
# Out:
# modelinin ortalama hatası : SalePrice    2.062065e-11
# dtype: float64

# %%
baslik_font = {'family': 'arial','color':  'darkred','weight': 'bold','size': 15 }
eksen_font = {'family': 'arial','color':  'darkblue','weight': 'bold','size': 10 }

plt.figure(figsize=(9,6), dpi=90)
plt.scatter(tahmin, hatalar)
plt.xlabel('Tahmin Edilen', fontdict=eksen_font)
plt.ylabel('Artık (Residual)', fontdict=eksen_font)
plt.axhline(y=0)
plt.title('Artık x Tahmin', fontdict=baslik_font)
plt.show()

# %%
from scipy.stats import bartlett
from scipy.stats import levene

bart_stats = bartlett(tahmin, hatalar)
lev_stats = levene(tahmin, hatalar)

print("Bartlett test değeri : {} ve p değeri : {}".format(bart_stats[0], bart_stats[1]))
print("Levene test değeri   : {} ve p değeri : {}".format(lev_stats[0], lev_stats[1]))
# Out:
# Bartlett test değeri : 327.28561044416244 ve p değeri : 3.7496637353682216e-73
# Levene test değeri   : [356.44146895] ve p değeri : [9.84635524e-75]

# %%
corr_mat = dff.corr()
corr_mat
# Out:
#              GrLivArea  OverallQual  GarageCars  SalePrice
# GrLivArea     1.000000     0.594470    0.483943   0.711706
# OverallQual   0.594470     1.000000    0.591878   0.783546
# GarageCars    0.483943     0.591878    1.000000   0.640154
# SalePrice     0.711706     0.783546    0.640154   1.000000

# %%
plt.figure(figsize=(9,6))
plt.plot(hatalar)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_data = acf(hatalar)

plt.figure(figsize=(9,6))
plt.plot(acf_data[1:])
plt.show()

# %%
dff['Hata'] = hatalar
dff.corr()
# Out:
# C:\Users\Ecem\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                 GrLivArea   OverallQual    GarageCars  SalePrice          Hata
# GrLivArea    1.000000e+00  5.944702e-01  4.839432e-01   0.711706  1.363200e-16
# OverallQual  5.944702e-01  1.000000e+00  5.918778e-01   0.783546  9.008770e-17
# GarageCars   4.839432e-01  5.918778e-01  1.000000e+00   0.640154  8.837698e-18
# SalePrice    7.117062e-01  7.835456e-01  6.401544e-01   1.000000  5.166957e-01
# Hata         1.363200e-16  9.008770e-17  8.837698e-18   0.516696  1.000000e+00

# %%
sns.heatmap(dff.corr(), annot=True)

# %%
from scipy.stats import jarque_bera
from scipy.stats import normaltest
jb_stats = jarque_bera(hatalar)
norm_stats = normaltest(hatalar)

print("Jarque-Bera test değeri : ", jb_stats)
print("Normal test değeri      : " , norm_stats)
# Out:
# Jarque-Bera test değeri :  (9184.846056891702, 0.0)
# Normal test değeri      :  NormaltestResult(statistic=array([359.00828191]), pvalue=array([1.10240736e-78]))

# %%
rand_nums = np.random.normal(np.mean(hatalar), np.std(hatalar), len(hatalar))

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(rand_nums, hatalar)
plt.xlabel("Normal dağılımlı rastgele değişken", fontdict=eksen_font)
plt.ylabel("Modelin hataları", fontdict=eksen_font)
plt.title("QQ plotu", fontdict=baslik_font)
# Out:
# Text(0.5, 1.0, 'QQ plotu')

# %% [markdown]
# Hatalar normal dağılım göstermemektedir
